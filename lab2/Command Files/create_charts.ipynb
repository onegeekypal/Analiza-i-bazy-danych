# %% [markdown]
# **imports and data**

# %%
import pandas
import matplotlib.pyplot as plt

renamed_question_table = pandas.read_csv('/Users/dawidsyty/DataspellProjects/Analiza-i-bazy-danych/lab2/Analysis Data/question_renamed.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/8n/vqpgygld0wq6vpqfk_zyb0hr0000gn/T/ipykernel_84019/1206638646.py in <module>
#       3
#       4 renamed_question_table = pandas.read_csv('/Users/dawidsyty/DataspellProjects/Analiza-i-bazy-danych/lab2/Analysis Data/question_renamed.csv')
# ----> 5 renamed_question_table.split()[0]
#
# ~/.conda/envs/untitled/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'split'

# %% [markdown]
# **Answers chars**

# %%
for column in renamed_question_table:
    answers = renamed_question_table[column].value_counts().to_dict()
    plt.figure(figsize=(20,10))
    plt.title(column)
    plt.bar(answers.keys(),answers.values())
    plt.savefig('/Users/dawidsyty/DataspellProjects/Analiza-i-bazy-danych/lab2/Analysis Data/charts/' + column + ".jpg")
    plt.show()
